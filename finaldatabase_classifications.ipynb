# %% [markdown]
# ### Importing Necessary Libraries

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import nltk
from nltk.corpus import stopwords
import string
from nltk import word_tokenize, FreqDist
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
import pandas as pd
import numpy as np
np.random.seed(0)
import re
import wordcloud

# %% [markdown]
# ### Loading and Basic Cleaning of Dataframe

# %%
df= pd.read_csv('final_database.csv')
df.head()
# Out:
#    Unnamed: 0  cuisine                                 recipe_ingredients  \
# 0           0  african  2 tbsp vegetable oil ½ tsp cumin seeds ½ tsp f...
# 1           1  african  1 tbsp olive or vegetable oil 2 large onions, ...
# 2           2  african  400ml/14fl oz passata 3 tbsp tomato purée 2 fr...
# 3           3  african  4g smoked paprika  2g cayenne pepper 6g ginger...
# 4           4  african  300g/10½oz basmati rice 1 tbsp vegetable oil 8...
#
#                                          recipe_name
# 0                                         Bunny chow
# 1                   Jollof rice with fried plantains
# 2                                        Jollof rice
# 3  Suya fillet burger with sweet potato cubes and...
# 4                          Jollof rice with chicken

# %%
df= df.drop_duplicates(subset='recipe_name')
df.describe()
# Out:
#         Unnamed: 0
# count  1687.000000
# mean    980.561944
# std     521.114071
# min       0.000000
# 25%     574.500000
# 50%     998.000000
# 75%    1426.500000
# max    1852.000000

# %%
df = df.drop(df.columns[0], axis=1)
df.describe()
# Out:
#        cuisine                                 recipe_ingredients  \
# count     1687                                               1687
# unique      14                                               1687
# top      greek  1 1/2 lb fresh apricots, quartered lengthwise ...
# freq       166                                                  1
#
#                       recipe_name
# count                        1687
# unique                       1687
# top     Grilled Stuffed Mackerel
# freq                            1

# %%
msk = (np.random.rand(len(df)) < 0.75)

# %%
train = df[msk]
len(train)
# Out:
# 1246

# %%
test = df[~msk]
len(test)
# Out:
# 441

# %%
print('train shape: ', train.shape)
print('test shape: ',  test.shape)
# Out:
# train shape:  (1246, 3)
# test shape:  (441, 3)

# %%
data_train= train['recipe_ingredients']
target_train= train['cuisine']
data_test= test['recipe_ingredients']
target_test= test['cuisine']
print(data_train.shape)
print(target_train.shape)
print(data_test.shape)
print(target_test.shape)
# Out:
# (1246,)
# (1246,)
# (441,)
# (441,)

# %%
train
# Out:
#        cuisine                                 recipe_ingredients  \
# 0      african  2 tbsp vegetable oil ½ tsp cumin seeds ½ tsp f...
# 1      african  1 tbsp olive or vegetable oil 2 large onions, ...
# 2      african  400ml/14fl oz passata 3 tbsp tomato purée 2 fr...
# 3      african  4g smoked paprika  2g cayenne pepper 6g ginger...
# 4      african  300g/10½oz basmati rice 1 tbsp vegetable oil 8...
# 5      african  2 tbsp ground ginger 1 tbsp ground cinnamon 1 ...
# 6      african  50ml/2fl oz olive oil 1 onion, chopped 2 garli...
# 9      african  2 tbsp groundnut oil 1 large chicken, jointed ...
# 11     african  1 butternut, peeled and sliced 2 large sweet p...
# 12     african  5 eggs 5 egg yolks 125g/4oz caster sugar 250g/...
# 14     african  4 chicken breasts, each cut into three long st...
# 15     african  1 tsp cloves 1 tsp fennel seeds  1 tsp black m...
# 16     african  3 tbsp olive oil 4 large onions, sliced 700g/1...
# 22     african  150g/5½oz millet couscous 150g/5½oz corn cousc...
# 24    american  450ml/16fl oz full-fat milk  3 large free-rang...
# 25    american  100g/3½oz unsalted butter 250g/9oz caster or b...
# 26    american  110g/4oz unsalted butter 110g/4oz golden syrup...
# 28    american  375g/13oz plain flour 225g/8oz cornmeal 1 tsp ...
# 29    american  1 tbsp yeast 4 tbsp caster sugar 150ml/5¼fl oz...
# 30    american  150ml/¼ pint sunflower oil 100g/4oz soft light...
# 32    american  sweet short crust pastry case (or a packet of ...
# 33    american  285g/10oz plain flour  1 tsp bicarbonate of so...
# 34    american  1 large free-range egg 1 large garlic clove, p...
# 35    american  6 tbsp hollandaise sauce  6 large, very fresh ...
# 36    american  400g/14oz plain flour  80g/3oz icing sugar 4 t...
# 37    american  100g/3½oz butter, plus extra for greasing 100g...
# 39    american  ¼ red onion, thinly sliced 400g tin cannellini...
# 40    american  75g/3oz melted butter  250g/9oz self-raising f...
# 41    american  1kg/2lb 4oz chicken wings, tips removed and sp...
# 42    american  400g tin chickpeas, drained and rinsed  1 iceb...
# ...        ...                                                ...
# 1660   chinese  2 tablespoons vegetable oil 8 ounces ground po...
# 1662   chinese  8 ounces lo mein noodles or spaghetti 1/2 teas...
# 1663   chinese  3 tablespoons peanut or vegetable oil 4 green ...
# 1664   chinese  4 slices bacon 1 cup vegetable oil 6 ounces sh...
# 1665   chinese  10 ounces shrimp, peeled, deveined 2 tablespoo...
# 1666   chinese  1/4 cup black vinegar 1/4 cup sherry vinegar 2...
# 1667   chinese  4 tablespoons salted butter, melted, plus more...
# 1668   chinese  1 tablespoon Chinkiang vinegar 1 teaspoon Sich...
# 1670   chinese  2 pounds brussels sprouts, halved 5 tablespoon...
# 1673   chinese  1/2 cup unsweetened coconut flakes 1 bunch wat...
# 1674   chinese  1 pound glutinous rice flour (also called swee...
# 1675   chinese  1 tablespoon soy sauce 2 teaspoons Chinese ric...
# 1676   chinese  2 large eggs, beaten 1/4 cup cornstarch 1/4 cu...
# 1677   chinese  1 pound baby bok choy 1 1/2 tablespoons soy sa...
# 1678   chinese  4 scallions, whites and greens separated, thin...
# 1679   chinese  1 pound boneless, skinless chicken thighs, pat...
# 1680   chinese  1 (2-pound) skin-on halibut fillet, rinsed and...
# 1681   chinese  1 turnip, cut into thin 1-inch strips 2 stalks...
# 1682   chinese  8 dried shiitake mushrooms 8 dried lily buds 1...
# 1685   chinese  1 rainbow trout (about 3/4 lb/350g), scaled an...
# 1686   chinese  1/2 oz (20g) piece of ginger, unpeeled 5 oz (1...
# 1689   chinese  12 ounces fresh Chinese thick, round egg noodl...
# 1690   chinese  3 cups all-purpose flour 1 cup boiling water 3...
# 1691   chinese  2 1/2 cups minced napa cabbage 1/2 teaspoon sa...
# 1692   chinese  2 tablespoons light soy sauce 1 tablespoon hoi...
# 1693   chinese  1/2 cup hoisin sauce 1/2 cup brandy, rum, or b...
# 1696   chinese  10 cups water; plus 6 tablespoons for glaze 12...
# 1697   chinese  5 pounds boneless beef shank 1/4 cup vegetable...
# 1698   chinese  2 10-ounce packages pickled mustard greens (su...
# 1699   chinese  1 duck (or chicken) breast, fat trimmed 1/2 te...
#
#                                             recipe_name
# 0                                            Bunny chow
# 1                      Jollof rice with fried plantains
# 2                                           Jollof rice
# 3     Suya fillet burger with sweet potato cubes and...
# 4                             Jollof rice with chicken
# 5                     Red-red stew with spiced plantain
# 6                                               Bobotie
# 9                                      Zanzibar chicken
# 11                                 Marinated vegetables
# 12                        Chocolate mealie meal pudding
# 14                     Swahili chicken and papaya salad
# 15                          Cape Malay vegetarian curry
# 16                   Chicken bastilla with orange salad
# 22    Senegalese couscous with beef and vegetable sauce
# 24                                              Waffles
# 25                                      Vanilla cupcake
# 26                                            Pecan pie
# 28                                            Cornbread
# 29                                            Doughnuts
# 30                                 Carrot cake traybake
# 32                                          Pumpkin pie
# 33                                         Banana bread
# 34                                         Caesar salad
# 35                                Cheat's eggs Benedict
# 36                      Key lime pie with ginger pastry
# 37                                         Mac & cheese
# 39                                        Avocado salad
# 40                                       Banana muffins
# 41                                        Buffalo wings
# 42                                        Chopped salad
# ...                                                 ...
# 1660              Weeknight Mapo Tofu with Ground Pork
# 1662                                 Easy Beef Lo Mein
# 1663  Rice Cakes With Salted Shanghainese Greens, Ba...
# 1664                      Crudités With Bacon XO Sauce
# 1665     Shrimp Toasts With Sesame Seeds and Scallions
# 1666  Stir-Fried Asparagus With Bacon and Crispy Sha...
# 1667             3-Ingredient Homemade Fortune Cookies
# 1668                           Chineasy Cucumber Salad
# 1670                         Kung Pao Brussels Sprouts
# 1673                                   Long Bean Salad
# 1674                              New Year's Rice Cake
# 1675                                  Kung Pao Chicken
# 1676                               Sweet and Sour Pork
# 1677                   Stir-Fried Sesame Baby Bok Choy
# 1678       Sesame Noodles with Chili Oil and Scallions
# 1679                            Chinese Orange Chicken
# 1680              Zesty Halibut in Soy-Ginger Dressing
# 1681                                       Spring Soup
# 1682                                  Buddha's Delight
# 1685   Braised Trout in Chilli Bean Sauce (Dou Ban Yu)
# 1686  Sichuanese Wontons in Chilli Oil Sauce (Hong Y...
# 1689             Chicken Lo Mein with Ginger Mushrooms
# 1690                                 Dumpling Wrappers
# 1691                                  Jiaozi Dumplings
# 1692                              Chicken Lettuce Cups
# 1693          Chinatown Char Siu Barbeque Ribs or Pork
# 1696                                     Sweet Walnuts
# 1697  Sichuan Beef Noodle Soup with Pickled Mustard ...
# 1698                            Pickled Mustard Greens
# 1699              Duck Pizza with Hoisin and Scallions
#
# [1246 rows x 3 columns]

# %% [markdown]
# ### Word Cleaning and Vectorizing

# %%
pattern = r"[a-z]+"
data_train = nltk.regexp_tokenize(str(data_train), pattern)
data_test= nltk.regexp_tokenize(str(data_test), pattern)

# %%
data_test
# Out:
# ['butter',
#  'for',
#  'greasing',
#  'ml',
#  'fl',
#  'oz',
#  'full',
#  'fat',
#  'mi',
#  'bone',
#  'in',
#  'chicken',
#  'thighs',
#  'or',
#  'drumsticks',
#  'large',
#  'tbsp',
#  'olive',
#  'oil',
#  'small',
#  'onion',
#  'chopped',
#  'carr',
#  'kg',
#  'lb',
#  'oz',
#  'goat',
#  'meat',
#  'cut',
#  'into',
#  'cm',
#  'in',
#  'piec',
#  'shoulder',
#  'of',
#  'lamb',
#  'approximately',
#  'kg',
#  'lb',
#  'oz',
#  'peppercorns',
#  'cardamom',
#  'pods',
#  'cloves',
#  'tbs',
#  'g',
#  'oz',
#  'salt',
#  'tsp',
#  'coriander',
#  'seeds',
#  'tsp',
#  'fenne',
#  'g',
#  'oz',
#  'ground',
#  'ginger',
#  'g',
#  'oz',
#  'garlic',
#  'granules',
#  'g',
#  'oz',
#  'dried',
#  'black',
#  'eyed',
#  'beans',
#  'g',
#  'lb',
#  'sirl',
#  'small',
#  'onion',
#  'chopped',
#  'cloves',
#  'garlic',
#  'crushe',
#  'g',
#  'oz',
#  'good',
#  'quality',
#  'black',
#  'cherry',
#  'jam',
#  'ml',
#  'g',
#  'oz',
#  'digestive',
#  'biscuits',
#  'g',
#  'oz',
#  'butter',
#  'g',
#  'g',
#  'oz',
#  'dark',
#  'chocolate',
#  'at',
#  'least',
#  'cocoa',
#  'so',
#  'g',
#  'oz',
#  'self',
#  'raising',
#  'flour',
#  'plus',
#  'extra',
#  'for',
#  'du',
#  'g',
#  'fl',
#  'oz',
#  'porridge',
#  'oats',
#  'g',
#  'oz',
#  'flaked',
#  'almon',
#  'ml',
#  'pint',
#  'double',
#  'cream',
#  'g',
#  'oz',
#  'porridge',
#  'oat',
#  'g',
#  'oz',
#  'butter',
#  'g',
#  'oz',
#  'golden',
#  'syrup',
#  'g',
#  'oz',
#  'tbsp',
#  'grated',
#  'fresh',
#  'root',
#  'ginger',
#  'tbsp',
#  'haoxin',
#  'g',
#  'lb',
#  'oz',
#  'beef',
#  'mince',
#  'garlic',
#  'cloves',
#  'finel',
#  'g',
#  'oz',
#  'strong',
#  'white',
#  'flour',
#  'plus',
#  'extra',
#  'for',
#  'du',
#  'ml',
#  'fl',
#  'oz',
#  'red',
#  'wine',
#  'tbsp',
#  'olive',
#  'oil',
#  'larg',
#  'g',
#  'oz',
#  'plain',
#  'flour',
#  'g',
#  'oz',
#  'ice',
#  'cold',
#  'butter',
#  'ml',
#  'fl',
#  'oz',
#  'double',
#  'cream',
#  'ml',
#  'fl',
#  'oz',
#  'whole',
#  'g',
#  'oz',
#  'butter',
#  'softened',
#  'g',
#  'oz',
#  'caster',
#  'sug',
#  'kg',
#  'lbs',
#  'dessert',
#  'apples',
#  'about',
#  'peeled',
#  't',
#  'g',
#  'oz',
#  'cr',
#  'me',
#  'fra',
#  'che',
#  'salt',
#  'and',
#  'freshly',
#  'groun',
#  'g',
#  'oz',
#  'black',
#  'alamata',
#  'olives',
#  'medium',
#  'tomato',
#  'tbsp',
#  'chopped',
#  'fresh',
#  'mint',
#  'tsp',
#  'finely',
#  'choppe',
#  'g',
#  'oz',
#  'plain',
#  'flour',
#  'tsp',
#  'sugar',
#  'tsp',
#  'salt',
#  'g',
#  'oz',
#  'basmati',
#  'rice',
#  'washed',
#  'litre',
#  'pints',
#  'cup',
#  'olive',
#  'oil',
#  'garlic',
#  'cloves',
#  'thinly',
#  'slic',
#  'tablespoons',
#  'balsamic',
#  'vinegar',
#  'cup',
#  'plus',
#  'pounds',
#  'sian',
#  'eggplants',
#  'about',
#  'trimme',
#  'ounces',
#  'pieces',
#  'acific',
#  'cod',
#  'or',
#  'hake',
#  'fillet',
#  'lb',
#  'erusalem',
#  'artichokes',
#  'also',
#  'called',
#  'un',
#  'ink',
#  'ady',
#  'or',
#  'ranny',
#  'mith',
#  'apple',
#  'cups',
#  'soju',
#  'tablespoons',
#  'white',
#  'miso',
#  'fermented',
#  'soybean',
#  'pa',
#  'pound',
#  'piece',
#  'center',
#  'cut',
#  'beef',
#  'tenderloin',
#  'pound',
#  'skirt',
#  'steak',
#  'silver',
#  'skin',
#  'removed',
#  'cut',
#  'inch',
#  'whole',
#  'wheat',
#  'tortillas',
#  'cup',
#  'refried',
#  'handfulls',
#  'baked',
#  'pita',
#  'chips',
#  'small',
#  'red',
#  'bell',
#  'tablespoons',
#  'vegetable',
#  'oil',
#  'whole',
#  'chicken',
#  'le',
#  'tablespoon',
#  'fresh',
#  'lemon',
#  'juice',
#  'teaspoon',
#  'suga',
#  'cups',
#  'thinly',
#  'sliced',
#  'red',
#  'and',
#  'or',
#  'white',
#  'cabbage',
#  'cups',
#  'hai',
#  'chicken',
#  'stock',
#  'to',
#  'teaspoons',
#  'nor',
#  'pound',
#  'skinless',
#  'boneless',
#  'chicken',
#  'breast',
#  'tab',
#  'cup',
#  'soy',
#  'sauce',
#  'cup',
#  'mirin',
#  'tablespoon',
#  't',
#  'lb',
#  'kg',
#  'whole',
#  'chicken',
#  'tablespoon',
#  'tablespoons',
#  'fermented',
#  'black',
#  'beans',
#  'tablespo',
#  'pounds',
#  'green',
#  'beans',
#  'divided',
#  'osher',
#  'salt',
#  'ta',
#  'pound',
#  'turkey',
#  'carcass',
#  'medium',
#  'onion',
#  'u',
#  'pounds',
#  'chicken',
#  'wings',
#  'cup',
#  'cornstarch',
#  'large',
#  'egg',
#  'ne',
#  'to',
#  'ounce',
#  'box',
#  'of',
#  'puff',
#  'pa',
#  'cups',
#  'hai',
#  'long',
#  'grain',
#  'sticky',
#  'rice',
#  'or',
#  'reg',
#  'tablespoons',
#  'sticks',
#  'unsalted',
#  'butter',
#  'ounces',
#  'thin',
#  'dried',
#  'hinese',
#  'egg',
#  'noodles',
#  'ta',
#  'lb',
#  'g',
#  'boneless',
#  'pork',
#  'belly',
#  'with',
#  'skin',
#  'pound',
#  'large',
#  'shrimp',
#  'uice',
#  'of',
#  'lime',
#  'table',
#  'cups',
#  'peanut',
#  'oil',
#  'pound',
#  'onions',
#  'very',
#  'thi',
#  'cups',
#  'water',
#  'tablespoon',
#  'salt',
#  'plus',
#  'teaspoon',
#  'ame',
#  'recipe',
#  'ingredients',
#  'ength',
#  'dtype',
#  'object']

# %%
# adapt this to do lower() separately
data_train= [i.lower() for i in data_train]
data_test= [i.lower() for i in data_test]

# %%
nltk.download('stopwords')

stopwords_list = stopwords.words('english')
#stopwords_list+= ["''", '""', '...', '``']
stopwords_list+= ['tsp','tbsp',
             'tablespoon', 'teaspoon', 'tablespoons', 'teaspoons', 
             'large', 'cup', 'ounces', 'pound', 'oz', 'slice','sliced', 
             'cup', 'cups', 'ounce', 'ounces', 'chopped', 'finely', 'cut',
            'thinly']
# Out:
# [nltk_data] Downloading package stopwords to /Users/Iffy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# do stopwords step on its own
processed_train=[w for w in data_train if not w in stopwords_list]
processed_test= [w for w in data_test if not w in stopwords_list]

# %%
print('cleaned train: ', processed_train)
print('----'*28)
print('cleaned test: ', processed_test)
# Out:
# cleaned train:  ['vegetable', 'oil', 'cumin', 'seeds', 'f', 'olive', 'vegetable', 'oil', 'onions', 'ml', 'fl', 'passata', 'tomato', 'pur', 'e', 'fr', 'g', 'smoked', 'paprika', 'g', 'cayenne', 'pepper', 'g', 'ginger', 'g', 'basmati', 'rice', 'vegetable', 'oil', 'ground', 'ginger', 'ground', 'cinnamon', 'ml', 'fl', 'olive', 'oil', 'onion', 'garli', 'groundnut', 'oil', 'chicken', 'jointed', 'butternut', 'peeled', 'sweet', 'p', 'eggs', 'egg', 'yolks', 'g', 'caster', 'sugar', 'g', 'chicken', 'breasts', 'three', 'long', 'st', 'cloves', 'fennel', 'seeds', 'black', 'olive', 'oil', 'onions', 'g', 'g', 'millet', 'couscous', 'g', 'corn', 'cousc', 'ml', 'fl', 'full', 'fat', 'milk', 'free', 'rang', 'g', 'unsalted', 'butter', 'g', 'caster', 'b', 'g', 'unsalted', 'butter', 'g', 'golden', 'syrup', 'g', 'plain', 'flour', 'g', 'cornmeal', 'yeast', 'caster', 'sugar', 'ml', 'fl', 'ml', 'pint', 'sunflower', 'oil', 'g', 'soft', 'light', 'sweet', 'short', 'crust', 'pastry', 'case', 'packet', 'g', 'plain', 'flour', 'bicarbonate', 'free', 'range', 'egg', 'garlic', 'clove', 'p', 'hollandaise', 'sauce', 'fresh', 'g', 'plain', 'flour', 'g', 'icing', 'sugar', 'g', 'butter', 'plus', 'extra', 'greasing', 'g', 'red', 'onion', 'g', 'tin', 'cannellini', 'g', 'melted', 'butter', 'g', 'self', 'raising', 'f', 'kg', 'lb', 'chicken', 'wings', 'tips', 'removed', 'sp', 'g', 'tin', 'chickpeas', 'drained', 'rinsed', 'iceb', 'vegetable', 'oil', 'ground', 'po', 'lo', 'mein', 'noodles', 'spaghetti', 'teas', 'peanut', 'vegetable', 'oil', 'green', 'slices', 'bacon', 'vegetable', 'oil', 'sh', 'shrimp', 'peeled', 'deveined', 'tablespoo', 'black', 'vinegar', 'sherry', 'vinegar', 'salted', 'butter', 'melted', 'plus', 'hinkiang', 'vinegar', 'ich', 'pounds', 'brussels', 'sprouts', 'halved', 'unsweetened', 'coconut', 'flakes', 'bunch', 'wat', 'glutinous', 'rice', 'flour', 'also', 'called', 'swee', 'soy', 'sauce', 'hinese', 'ric', 'eggs', 'beaten', 'cornstarch', 'cu', 'baby', 'bok', 'choy', 'soy', 'sa', 'scallions', 'whites', 'greens', 'separated', 'thin', 'boneless', 'skinless', 'chicken', 'thighs', 'pat', 'skin', 'halibut', 'fillet', 'rinsed', 'turnip', 'thin', 'inch', 'strips', 'stalks', 'dried', 'shiitake', 'mushrooms', 'dried', 'lily', 'buds', 'rainbow', 'trout', 'lb', 'g', 'scaled', 'g', 'piece', 'ginger', 'unpeeled', 'fresh', 'hinese', 'thick', 'round', 'egg', 'noodl', 'purpose', 'flour', 'boiling', 'water', 'minced', 'napa', 'cabbage', 'sa', 'light', 'soy', 'sauce', 'hoi', 'hoisin', 'sauce', 'brandy', 'rum', 'b', 'water', 'plus', 'glaze', 'pounds', 'boneless', 'beef', 'shank', 'vegetable', 'packages', 'pickled', 'mustard', 'greens', 'su', 'duck', 'chicken', 'breast', 'fat', 'trimmed', 'te', 'ame', 'recipe', 'ingredients', 'ength', 'dtype', 'object']
# ----------------------------------------------------------------------------------------------------------------
# cleaned test:  ['butter', 'greasing', 'ml', 'fl', 'full', 'fat', 'mi', 'bone', 'chicken', 'thighs', 'drumsticks', 'olive', 'oil', 'small', 'onion', 'carr', 'kg', 'lb', 'goat', 'meat', 'cm', 'piec', 'shoulder', 'lamb', 'approximately', 'kg', 'lb', 'peppercorns', 'cardamom', 'pods', 'cloves', 'tbs', 'g', 'salt', 'coriander', 'seeds', 'fenne', 'g', 'ground', 'ginger', 'g', 'garlic', 'granules', 'g', 'dried', 'black', 'eyed', 'beans', 'g', 'lb', 'sirl', 'small', 'onion', 'cloves', 'garlic', 'crushe', 'g', 'good', 'quality', 'black', 'cherry', 'jam', 'ml', 'g', 'digestive', 'biscuits', 'g', 'butter', 'g', 'g', 'dark', 'chocolate', 'least', 'cocoa', 'g', 'self', 'raising', 'flour', 'plus', 'extra', 'du', 'g', 'fl', 'porridge', 'oats', 'g', 'flaked', 'almon', 'ml', 'pint', 'double', 'cream', 'g', 'porridge', 'oat', 'g', 'butter', 'g', 'golden', 'syrup', 'g', 'grated', 'fresh', 'root', 'ginger', 'haoxin', 'g', 'lb', 'beef', 'mince', 'garlic', 'cloves', 'finel', 'g', 'strong', 'white', 'flour', 'plus', 'extra', 'du', 'ml', 'fl', 'red', 'wine', 'olive', 'oil', 'larg', 'g', 'plain', 'flour', 'g', 'ice', 'cold', 'butter', 'ml', 'fl', 'double', 'cream', 'ml', 'fl', 'whole', 'g', 'butter', 'softened', 'g', 'caster', 'sug', 'kg', 'lbs', 'dessert', 'apples', 'peeled', 'g', 'cr', 'fra', 'che', 'salt', 'freshly', 'groun', 'g', 'black', 'alamata', 'olives', 'medium', 'tomato', 'fresh', 'mint', 'choppe', 'g', 'plain', 'flour', 'sugar', 'salt', 'g', 'basmati', 'rice', 'washed', 'litre', 'pints', 'olive', 'oil', 'garlic', 'cloves', 'slic', 'balsamic', 'vinegar', 'plus', 'pounds', 'sian', 'eggplants', 'trimme', 'pieces', 'acific', 'cod', 'hake', 'fillet', 'lb', 'erusalem', 'artichokes', 'also', 'called', 'un', 'ink', 'ady', 'ranny', 'mith', 'apple', 'soju', 'white', 'miso', 'fermented', 'soybean', 'pa', 'piece', 'center', 'beef', 'tenderloin', 'skirt', 'steak', 'silver', 'skin', 'removed', 'inch', 'whole', 'wheat', 'tortillas', 'refried', 'handfulls', 'baked', 'pita', 'chips', 'small', 'red', 'bell', 'vegetable', 'oil', 'whole', 'chicken', 'le', 'fresh', 'lemon', 'juice', 'suga', 'red', 'white', 'cabbage', 'hai', 'chicken', 'stock', 'skinless', 'boneless', 'chicken', 'breast', 'tab', 'soy', 'sauce', 'mirin', 'lb', 'kg', 'whole', 'chicken', 'fermented', 'black', 'beans', 'tablespo', 'pounds', 'green', 'beans', 'divided', 'osher', 'salt', 'ta', 'turkey', 'carcass', 'medium', 'onion', 'u', 'pounds', 'chicken', 'wings', 'cornstarch', 'egg', 'ne', 'box', 'puff', 'pa', 'hai', 'long', 'grain', 'sticky', 'rice', 'reg', 'sticks', 'unsalted', 'butter', 'thin', 'dried', 'hinese', 'egg', 'noodles', 'ta', 'lb', 'g', 'boneless', 'pork', 'belly', 'skin', 'shrimp', 'uice', 'lime', 'table', 'peanut', 'oil', 'onions', 'thi', 'water', 'salt', 'plus', 'ame', 'recipe', 'ingredients', 'ength', 'dtype', 'object']

# %%
ptrain= processed_train
len(ptrain)
# Out:
# 308

# %%
# ptest= p.findall(str(processed_test))
ptest= processed_test
len(ptest)
# Out:
# 324

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# %%
tf_idf_ptrain = vectorizer.fit_transform(ptrain)
tf_idf_ptest = vectorizer.transform(ptest)
print('vectorized trained processed data: ',tf_idf_ptrain.shape)
print('vectorized test processed data: ', tf_idf_ptest.shape)
# Out:
# vectorized trained processed data:  (308, 192)
# vectorized test processed data:  (324, 192)

# %%
tf_idf_data_train= vectorizer.fit_transform(data_train)
tf_idf_data_test = vectorizer.transform(data_test)
print('vectorized trained data: ', tf_idf_data_train)
print('vectorizer test data: ', tf_idf_data_test)
# Out:
# vectorized trained data:    (0, 2877)	0.32715622836717667
#   (0, 3050)	0.05034955389067481
#   (0, 2003)	0.031451702542290905
#   (0, 2982)	0.11442879678825343
#   (0, 1011)	0.06751769769022144
#   (0, 2525)	0.11201333878743083
#   (0, 1201)	0.09856758613165911
#   (0, 281)	0.19713517226331823
#   (0, 89)	0.11041046315539162
#   (0, 2163)	0.07305098534397828
#   (0, 2000)	0.20419723281414084
#   (0, 862)	0.0705497470656639
#   (0, 2773)	0.06914748960540358
#   (0, 1413)	0.05911578065781837
#   (0, 754)	0.09155189721018657
#   (0, 2225)	0.09658030010987209
#   (0, 2759)	0.11445875615343808
#   (0, 433)	0.11041046315539162
#   (0, 534)	0.07891352833696692
#   (0, 1678)	0.0778575699647505
#   (0, 2014)	0.050836905128373085
#   (0, 1221)	0.1865598907745209
#   (0, 844)	0.173630890197736
#   (0, 2698)	0.15503238686959475
#   (0, 390)	0.14657814679450507
#   :	:
#   (1245, 1195)	0.1444300634774966
#   (1245, 2880)	0.26598571086013223
#   (1245, 1924)	0.21007830217244047
#   (1245, 2979)	0.12138680163439758
#   (1245, 3119)	0.10248642053286368
#   (1245, 941)	0.16005880228385738
#   (1245, 2547)	0.12025870814018189
#   (1245, 659)	0.18275686007884398
#   (1245, 831)	0.17474950322869312
#   (1245, 3106)	0.1662037699383617
#   (1245, 2523)	0.13899704052850206
#   (1245, 1239)	0.2251714312141888
#   (1245, 485)	0.15621784788006407
#   (1245, 1500)	0.22078704764938548
#   (1245, 2721)	0.16526133386847638
#   (1245, 2089)	0.21686508290586307
#   (1245, 1012)	0.10833726711726688
#   (1245, 2253)	0.09487587260285972
#   (1245, 2851)	0.12329781230411074
#   (1245, 553)	0.16344515726276734
#   (1245, 1104)	0.1971128514405058
#   (1245, 1124)	0.22078704764938548
#   (1245, 2497)	0.1334563756976561
#   (1245, 2199)	0.2358801766911338
#   (1245, 2627)	0.23014203534190242
# vectorizer test data:    (0, 3141)	0.14773519085963868
#   (0, 3115)	0.06757979508739496
#   (0, 3071)	0.07926186443124868
#   (0, 2877)	0.35637055515000576
#   (0, 2780)	0.09771528082840955
#   (0, 2483)	0.06825999515490425
#   (0, 2344)	0.10460635199428699
#   (0, 2340)	0.12100251909747717
#   (0, 2097)	0.08666425883576175
#   (0, 2048)	0.15427401813704242
#   (0, 2015)	0.08062112982688051
#   (0, 2009)	0.060740841965331034
#   (0, 2003)	0.04111232392432212
#   (0, 1886)	0.1496156035632019
#   (0, 1879)	0.0749135323441746
#   (0, 1798)	0.1443238476446643
#   (0, 1770)	0.16850745044060653
#   (0, 1678)	0.1017720942784373
#   (0, 1666)	0.053504034571814456
#   (0, 1661)	0.2122845221486249
#   (0, 1410)	0.13729667045909447
#   (0, 1336)	0.051410689739880014
#   (0, 1318)	0.14129237362835656
#   (0, 1300)	0.047376449733086703
#   (0, 1294)	0.1017720942784373
#   :	:
#   (440, 2003)	0.0840701539002282
#   (440, 2000)	0.06822719996478105
#   (440, 1855)	0.07425594913913838
#   (440, 1710)	0.11535539520793286
#   (440, 1709)	0.09428945993396327
#   (440, 1683)	0.07071252762512659
#   (440, 1538)	0.13050622121047242
#   (440, 1429)	0.052294817430439185
#   (440, 1402)	0.07009552291825276
#   (440, 1356)	0.07344140951181545
#   (440, 1264)	0.07081670310160625
#   (440, 1233)	0.1878843079360688
#   (440, 1221)	0.06233414036940607
#   (440, 1146)	0.08474046817591437
#   (440, 1013)	0.1559235138664693
#   (440, 1012)	0.16220746980698392
#   (440, 951)	0.13173519183135127
#   (440, 848)	0.3445790930708243
#   (440, 613)	0.3371368791362984
#   (440, 566)	0.16528619060787098
#   (440, 540)	0.10050778063874269
#   (440, 501)	0.09961357854514913
#   (440, 428)	0.04958517566361697
#   (440, 403)	0.08389338449083636
#   (440, 45)	0.10934426436096575

# %%
non_zero_cols = tf_idf_ptrain.nnz / float(tf_idf_ptrain.shape[0])
print("Average Number of Non-Zero Elements in Vectorized Articles: {}".format(non_zero_cols))

percent_sparse = 1 - (non_zero_cols / float(tf_idf_ptrain.shape[1]))
print('Percentage of columns containing 0: {}'.format(percent_sparse))
# Out:
# Average Number of Non-Zero Elements in Vectorized Articles: 0.8896103896103896
# Percentage of columns containing 0: 0.9953666125541125

# %% [markdown]
# ## Finding the Best Model

# %% [markdown]
# ### Naive Bayes and Random Forest

# %%
nb_classifier = MultinomialNB()
rf_classifier = RandomForestClassifier(n_estimators=100)

# %%
nb_classifier.fit(tf_idf_ptrain, ptrain)
nb_train_preds = nb_classifier.predict(tf_idf_ptrain)
nb_test_preds = nb_classifier.predict(tf_idf_ptest)

# %%
rf_classifier.fit(tf_idf_ptrain, ptrain)
rf_train_preds = rf_classifier.predict(tf_idf_ptrain)
rf_test_preds = rf_classifier.predict(tf_idf_ptest)

# %%
nb_train_score = accuracy_score(ptrain, nb_train_preds)
nb_test_score = accuracy_score(ptest, nb_test_preds)
rf_train_score = accuracy_score(ptrain, rf_train_preds)
rf_test_score = accuracy_score(ptest, rf_test_preds)

print("Multinomial Naive Bayes")
print("Training Accuracy: {:.4} \t\t Testing Accuracy: {:.4}".format(nb_train_score, nb_test_score))
print("")
print('-'*70)
print("")
print('Random Forest')
print("Training Accuracy: {:.4} \t\t Testing Accuracy: {:.4}".format(rf_train_score, rf_test_score))
# Out:
# Multinomial Naive Bayes
# Training Accuracy: 0.2078 		 Testing Accuracy: 0.1728
#
# ----------------------------------------------------------------------
#
# Random Forest
# Training Accuracy: 0.9773 		 Testing Accuracy: 0.5154
